# %%
from models import run_model
import torch
from torch import nn

# %% [markdown]
# 2 layers best params:

# %%
run_model(nn.CrossEntropyLoss(), lr=0.001731, epochs=100, model_conf=10, batch_size=8, disable_msg=True)
# Out:
#         Metrics for model MLP on Test data 10:
#         -- Accuracy: 42.70 %
#         -- Recall: 35.70 %
#         -- Precision: 62.92 %
#         -- F1: 45.55 %
#         -- Loss: 1.65
#
#
#         Metrics for model MLP on Train data 10:
#         -- Accuracy: 44.61 %
#         -- Recall: 51.03 %
#         -- Precision: 65.12 %
#         -- F1: 57.22 %
#         -- Loss: 1.63

# %% [markdown]
# 3 layers best params:

# %%
run_model(nn.CrossEntropyLoss(), lr=0.00606, epochs=70, model_conf=12, batch_size=32)
# Out:
# Epoch 1 ---------------------
# Loss: 1.611617122626886
# Epoch 2 ---------------------
# Loss: 1.5941727298062023
# Epoch 3 ---------------------
# Loss: 1.5946182191371918
# Epoch 4 ---------------------
# Loss: 1.593791804662565
# Epoch 5 ---------------------
# Loss: 1.6120275177606722
# Epoch 6 ---------------------
# Loss: 1.5915727230106913
# Epoch 7 ---------------------
# Loss: 1.614830930785435
# Epoch 8 ---------------------
# Loss: 1.6020464365075273
# Epoch 9 ---------------------
# Loss: 1.6090321122146234
# Epoch 10 ---------------------
# Loss: 1.5958939989892449
# Epoch 11 ---------------------
# Loss: 1.6307365869603505
# Epoch 12 ---------------------
# Loss: 1.6114087287972614
# Epoch 13 ---------------------
# Loss: 1.6296981260543917
# Epoch 14 ---------------------
# Loss: 1.627682938808348
# Epoch 15 ---------------------
# Loss: 1.6327014148235321
# Epoch 16 ---------------------
# Loss: 1.6603769133730633
# Epoch 17 ---------------------
# ...

# %% [markdown]
# 4 layers

# %%
run_model(nn.CrossEntropyLoss(), lr=0.0001, epochs=70, model_conf=11, batch_size=64)
# Out:
# Epoch 1 ---------------------
# Loss: 1.6421539463647983
# Epoch 2 ---------------------
# Loss: 1.5694732907341749
# Epoch 3 ---------------------
# Loss: 1.5579154378030358
# Epoch 4 ---------------------
# Loss: 1.5484347910415837
# Epoch 5 ---------------------
# Loss: 1.54186139339354
# Epoch 6 ---------------------
# Loss: 1.5353071227306272
# Epoch 7 ---------------------
# Loss: 1.5297885292913855
# Epoch 8 ---------------------
# Loss: 1.528209952610295
# Epoch 9 ---------------------
# Loss: 1.5245743966684109
# Epoch 10 ---------------------
# Loss: 1.5210601158258392
# Epoch 11 ---------------------
# Loss: 1.5186506884854014
# Epoch 12 ---------------------
# Loss: 1.516800612647359
# Epoch 13 ---------------------
# Loss: 1.5134572831595816
# Epoch 14 ---------------------
# Loss: 1.5139928093770656
# Epoch 15 ---------------------
# Loss: 1.5117205805894804
# Epoch 16 ---------------------
# Loss: 1.5103415178089608
# Epoch 17 ---------------------
# ...

# %% [markdown]
# additional model

# %%
run_model(nn.CrossEntropyLoss(), lr=0.001, epochs=70, model_conf=13, batch_size="full")
# Out:
# Epoch 1 ---------------------
# Loss: 1.792529582977295
# Epoch 2 ---------------------
# Loss: 1.7854450941085815
# Epoch 3 ---------------------
# Loss: 1.7773042917251587
# Epoch 4 ---------------------
# Loss: 1.7666521072387695
# Epoch 5 ---------------------
# Loss: 1.7526087760925293
# Epoch 6 ---------------------
# Loss: 1.7358336448669434
# Epoch 7 ---------------------
# Loss: 1.7172372341156006
# Epoch 8 ---------------------
# Loss: 1.6962846517562866
# Epoch 9 ---------------------
# Loss: 1.6777199506759644
# Epoch 10 ---------------------
# Loss: 1.6608260869979858
# Epoch 11 ---------------------
# Loss: 1.647233486175537
# Epoch 12 ---------------------
# Loss: 1.6344279050827026
# Epoch 13 ---------------------
# Loss: 1.624182939529419
# Epoch 14 ---------------------
# Loss: 1.6141825914382935
# Epoch 15 ---------------------
# Loss: 1.6061311960220337
# Epoch 16 ---------------------
# Loss: 1.6019926071166992
# Epoch 17 ---------------------
# ...
